# %%
# %pip list
# Out:
# Package                                  Version
# ---------------------------------------- ---------------
# absl-py                                  1.4.0
# aiohttp                                  3.8.5
# aiohttp-cors                             0.7.0
# aiorwlock                                1.3.0
# aiosignal                                1.3.1
# ansiwrap                                 0.8.4
# anyio                                    3.7.1
# apache-beam                              2.46.0
# argon2-cffi                              21.3.0
# argon2-cffi-bindings                     21.2.0
# array-record                             0.4.1
# arrow                                    1.2.3
# asttokens                                2.2.1
# astunparse                               1.6.3
# async-lru                                2.0.4
# async-timeout                            4.0.3
# attrs                                    23.1.0
# Babel                                    2.12.1
# ...

# %%
import pandas as pd

# %%
import xgboost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import xgboost
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# %pip install xgboost
# Out:
# ...
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/c1/cf/a662bc8f40588d54663edfe12980946670490bff0b6e793c7896a4fe36df/xgboost-2.0.0-py3-none-manylinux2014_x86_64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 3.0 MB/s eta 0:00:00:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost

# %%
# %%bigquery
# SELECT * FROM `bigquery-public-data.san_francisco_trees.street_trees` LIMIT 15
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     tree_id    legal_status                                       species  \
# 0     36561  Permitted Site                                    Tree(s) ::
# 1     44943  Permitted Site                                    Tree(s) ::
# 2     30483  Permitted Site                                    Tree(s) ::
# 3     46142  Permitted Site         Lophostemon confertus :: Brisbane Box
# 4     44538  Permitted Site                                    Tree(s) ::
# 5     44962  Permitted Site                                    Tree(s) ::
# 6     48065  Permitted Site                                    Tree(s) ::
# 7     44553  Permitted Site                                    Tree(s) ::
# 8     45022  Permitted Site                                    Tree(s) ::
# 9     48259  Permitted Site                                    Tree(s) ::
# 10    48208  Permitted Site                                    Tree(s) ::
# ...

# %%
# %%bigquery df_tree
# SELECT species, count(*) ,min(plant_date) as mbbm,max(plant_date) as hi FROM `bigquery-public-data.san_francisco_trees.street_trees`
# group by species
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_tree
# Out:
#                                                species    f0_  \
# 0                                           Tree(s) ::  11810
# 1                Lophostemon confertus :: Brisbane Box   8988
# 2         Melaleuca linariifolia :: Flaxleaf Paperbark    371
# 3                          Robinia x ambigua :: Locust    118
# 4           Arbutus 'Marina' :: Hybrid Strawberry Tree   5792
# ..                                                 ...    ...
# 576                 Rhopalostylis sapida :: Nikau palm      1
# 577  Viburnum odoratissimum var. awabuki :: Sweet v...      6
# 578  Callistemon salignus :: White flowering bottle...      1
# 579                 Macadamia tetraphylla :: Macadamia      1
# 580                  Corylus colurna :: Hazel: Turkish      2
#
#                          mbbm                        hi
# 0   1955-09-19 12:00:00+00:00 2023-06-23 12:00:00+00:00
# 1   1969-07-28 12:00:00+00:00 2023-08-21 08:03:00+00:00
# ...
